# %% [markdown]
# <a href="https://colab.research.google.com/github/SurekhaBerlin/Python/blob/main/BankingProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA PREPARATION:
#
#
# Import the libraries
#
# Importing the Excel files
#
# *   ActiveCustomer.xlsx
# *   Bank_Churn.csv
# *   CreditCard.xlxs
# *   Customerinfo.csv
# *   ExitCustomer.xlxs
# *   Gender.xlxs
# *   Geography.xlxs
#
# Seperating each excel sheet to a seperate csv files named
#
# *   ActiveCustomer.csv
# *   CreditCard.csv
# *   ExitCustomer.csv
# *   Gender.csv
# *   Geography.csv

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %% [markdown]
# ## Converting to CSV file

# %%
# Read the Excel file
excel_file = pd.read_excel('ActiveCustomer.xlsx')

# Convert Excel to CSV
excel_file.to_csv('ActiveCustomer.csv', index=False)

# %%
# Read the Excel file
excel_file = pd.read_excel('CreditCard.xlsx')

# Convert Excel to CSV
excel_file.to_csv('CreditCard.csv', index=False)

# %%
# Read the Excel file
excel_file = pd.read_excel('ExitCustomer.xlsx')

# Convert Excel to CSV
excel_file.to_csv('ExitCustomer.csv', index=False)

# %%
# Read the Excel file
excel_file = pd.read_excel('Gender.xlsx')

# Convert Excel to CSV
excel_file.to_csv('Gender.csv', index=False)

# %%
# Read the Excel file
excel_file = pd.read_excel('Geography.xlsx')

# Convert Excel to CSV
excel_file.to_csv('Geography.csv', index=False)

# %% [markdown]
# ## DATA OVERVIEW

# %%
# Reading the data
## Importing the ActiveCustomer.csv file into a pandas data frame

ActiveCustomers= pd.read_csv("/content/ActiveCustomer.csv")

# %%
ActiveCustomers.shape
# Out:
# (2, 2)

# %%
ActiveCustomers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ActiveID        2 non-null      int64
#  1   ActiveCategory  2 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 160.0+ bytes

# %%
ActiveCustomers.describe()
# Out:
#        ActiveID
# count  2.000000
# mean   0.500000
# std    0.707107
# min    0.000000
# 25%    0.250000
# 50%    0.500000
# 75%    0.750000
# max    1.000000

# %%
ActiveCustomers.head()
# Out:
#    ActiveID   ActiveCategory
# 0         1    Active Member
# 1         0  Inactive Member

# %%
Bank_Churn = pd.read_csv("/content/Bank_Churn.csv")

# %%
Bank_Churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   CreditScore      10000 non-null  int64
#  3   GeographyID      10000 non-null  int64
#  4   GenderID         10000 non-null  int64
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
#  13  Bank DOJ         10000 non-null  object
# dtypes: float64(2), int64(11), object(1)
# memory usage: 1.1+ MB

# %%
Bank_Churn.describe()
# Out:
#          RowNumber    CustomerId   CreditScore   GeographyID      GenderID  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800      1.749500      1.454300
# std     2886.89568  7.193619e+04     96.653299      0.830433      0.497932
# min        1.00000  1.556570e+07    350.000000      1.000000      1.000000
# 25%     2500.75000  1.562853e+07    584.000000      1.000000      1.000000
# 50%     5000.50000  1.569074e+07    652.000000      1.000000      1.000000
# 75%     7500.25000  1.575323e+07    718.000000      3.000000      2.000000
# max    10000.00000  1.581569e+07    850.000000      3.000000      2.000000
#
#                 Age       Tenure        Balance  NumOfProducts    HasCrCard  \
# count  10000.000000  10000.00000   10000.000000   10000.000000  10000.00000
# mean      38.921800      4.86430   76485.889288       1.530200      0.70550
# ...

# %%
Bank_Churn.head(5)
# Out:
#    RowNumber  CustomerId  CreditScore  GeographyID  GenderID  Age  Tenure  \
# 0          1    15634602          619            1         2   42       7
# 1          2    15647311          608            2         2   41       4
# 2          3    15619304          502            1         2   42       4
# 3          4    15701354          699            1         2   39       3
# 4          5    15737888          850            2         2   43       3
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited    Bank DOJ
# 0       1  23-03-2016
# 1       0  09-10-2018
# ...

# %%
CrediCard = pd.read_csv("/content/CreditCard.csv")

# %%
CrediCard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CreditID  2 non-null      int64
#  1   Category  2 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 160.0+ bytes

# %%
CrediCard.head()
# Out:
#    CreditID                Category
# 0         1      credit card holder
# 1         0  non credit card holder

# %%
CrediCard.describe()
# Out:
#        CreditID
# count  2.000000
# mean   0.500000
# std    0.707107
# min    0.000000
# 25%    0.250000
# 50%    0.500000
# 75%    0.750000
# max    1.000000

# %%
CustomerInfo = pd.read_csv("/content/CustomerInfo.csv")

# %%
CustomerInfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerId  10000 non-null  int64
#  1   Surname     10000 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 156.4+ KB

# %%
CustomerInfo.head()
# Out:
#    CustomerId   Surname
# 0    15634602  Hargrave
# 1    15647311      Hill
# 2    15619304      Onio
# 3    15701354      Boni
# 4    15737888  Mitchell

# %%
ExitCustomer = pd.read_csv("/content/ExitCustomer.csv")

# %%
ExitCustomer .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ExitID        2 non-null      int64
#  1   ExitCategory  2 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 160.0+ bytes

# %%
Gender = pd.read_csv("/content/Gender.csv")

# %%
Gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GenderID        2 non-null      int64
#  1   GenderCategory  2 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 160.0+ bytes

# %%
Geography = pd.read_csv("/content/Geography.csv")

# %%
Geography.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GeographyID        3 non-null      int64
#  1   GeographyLocation  3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
Bank_Churn.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# CreditScore        0
# GeographyID        0
# GenderID           0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# Bank DOJ           0
# dtype: int64

# %%
CustomerInfo.isnull().sum()
# Out:
# CustomerId    0
# Surname       0
# dtype: int64
